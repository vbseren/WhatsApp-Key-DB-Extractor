# %% [markdown]
# <a href="https://colab.research.google.com/github/vbseren/WhatsApp-Key-DB-Extractor/blob/master/MODULO1_Analisis_de_series_temporales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importar biliotecas
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

from statsmodels.tsa.seasonal import seasonal_decompose as sd
from statsmodels.tsa.arima.model import ARIMA

# %%
# cargar datos (Aseurarse de que el Dataframe tenga el respectivo indice y fecha)
df=pd.read_csv('tus_datos.csv', index_col='Fecha', parse_dates=True)

# %%
df
# Out:
#             Estacionaria  No_Estacionaria  Estacionalidad    Ciclos  \
# Fecha
# 2020-01-31      1.764052        19.415753       -1.845909 -6.532634
# 2020-02-29      0.400157         3.665245       -0.562657  9.556578
# 2020-03-31      0.978738         4.455656        6.764223  1.920660
# 2020-04-30      2.240893        16.059105        5.168831  0.315734
# 2020-05-31      1.867558         5.750545        5.712138  8.193883
# ...                  ...              ...             ...       ...
# 2027-12-31      0.706573        47.526107        3.172977 -8.669428
# 2028-01-31      0.010500        52.646832       -1.403888  0.572995
# 2028-02-29      1.785870        53.309440        1.648844  3.194029
# 2028-03-31      0.126912        60.412139       -2.631484  6.066969
# 2028-04-30      0.401989        56.682640        1.850279  4.262760
#
#             Irregular      Mixta
# Fecha
# 2020-01-31  -0.598654  11.913662
# 2020-02-29  -1.115897  10.867068
# ...

# %%
# Graficar el comportamiento de los dato, es una grafica muy general como un ounto de arranque para visualizar datos cuando en cuetion del tiempo, indice que tiene 2 cilumnas, una que tiene tiempo y otr que tiene obervaciones con respecto al tiempo
df.plot()
# Out:
# <Axes: xlabel='Fecha'>

# %%
plt.show()

# %%
# Descomposicion de la serie temporal [ conlumna de fecha contra estacionaria]
descomposition=sd(df['No_Estacionaria'], model='additive')
descomposition.plot()
plt.show() # solo cisualiza unica grafica, si no se coloca genera grafica repetida

# %%
# Trend: tendencia
# Seasonal: estacionalidad
# Resid: Ruido
